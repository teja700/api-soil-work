# %%
import pandas as pd
dataset=pd.read_csv('crop.csv')
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[2], line 2
#       1 import pandas as pd
# ----> 2 dataset=pd.read_csv('crop.csv')
#
# File c:\Users\LENOVO\AppData\Local\Programs\Python\Python313\Lib\site-packages\pandas\io\parsers\readers.py:1026, in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, date_format, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options, dtype_backend)
#    1013 kwds_defaults = _refine_defaults_read(
#    1014     dialect,
#    1015     delimiter,
#    (...)
#    1022     dtype_backend=dtype_backend,
#    1023 )
#    1024 kwds.update(kwds_defaults)
# -> 1026 return _read(filepath_or_buffer, kwds)
#
# File c:\Users\LENOVO\AppData\Local\Programs\Python\Python313\Lib\site-packages\pandas\io\parsers\readers.py:620, in _read(filepath_or_buffer, kwds)
#     617 _validate_names(kwds.get("names", None))
#     619 # Create the parser.
# --> 620 parser = TextFileReader(filepath_or_buffer, **kwds)
#     622 if chunksize or iterator:
#     623     return parser
#
# File c:\Users\LENOVO\AppData\Local\Programs\Python\Python313\Lib\site-packages\pandas\io\parsers\readers.py:1620, in TextFileReader.__init__(self, f, engine, **kwds)
#    1617     self.options["has_index_names"] = kwds["has_index_names"]
#    1619 self.handles: IOHandles | None = None
# -> 1620 self._engine = self._make_engine(f, self.engine)
#
# File c:\Users\LENOVO\AppData\Local\Programs\Python\Python313\Lib\site-packages\pandas\io\parsers\readers.py:1880, in TextFileReader._make_engine(self, f, engine)
#    1878     if "b" not in mode:
#    1879         mode += "b"
# -> 1880 self.handles = get_handle(
#    1881     f,
#    1882     mode,
#    1883     encoding=self.options.get("encoding", None),
#    1884     compression=self.options.get("compression", None),
#    1885     memory_map=self.options.get("memory_map", False),
#    1886     is_text=is_text,
#    1887     errors=self.options.get("encoding_errors", "strict"),
#    1888     storage_options=self.options.get("storage_options", None),
#    1889 )
#    1890 assert self.handles is not None
#    1891 f = self.handles.handle
#
# File c:\Users\LENOVO\AppData\Local\Programs\Python\Python313\Lib\site-packages\pandas\io\common.py:873, in get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text, errors, storage_options)
#     868 elif isinstance(handle, str):
#     869     # Check whether the filename is to be opened in binary mode.
#     870     # Binary mode does not support 'encoding' and 'newline'.
#     871     if ioargs.encoding and "b" not in ioargs.mode:
#     872         # Encoding
# --> 873         handle = open(
#     874             handle,
#     875             ioargs.mode,
#     876             encoding=ioargs.encoding,
#     877             errors=errors,
#     878             newline="",
#     879         )
#     880     else:
#     881         # Binary mode
#     882         handle = open(handle, ioargs.mode)
#
# FileNotFoundError: [Errno 2] No such file or directory: 'crop.csv'

# %%
dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2200 entries, 0 to 2199
# Data columns (total 8 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   N            2200 non-null   int64
#  1   P            2200 non-null   int64
#  2   K            2200 non-null   int64
#  3   temperature  2200 non-null   float64
#  4   humidity     2200 non-null   float64
#  5   ph           2200 non-null   float64
#  6   rainfall     2200 non-null   float64
#  7   label        2200 non-null   object
# dtypes: float64(4), int64(3), object(1)
# memory usage: 137.6+ KB

# %%
dataset
# Out:
#         N   P   K  temperature   humidity        ph    rainfall   label
# 0      90  42  43    20.879744  82.002744  6.502985  202.935536    rice
# 1      85  58  41    21.770462  80.319644  7.038096  226.655537    rice
# 2      60  55  44    23.004459  82.320763  7.840207  263.964248    rice
# 3      74  35  40    26.491096  80.158363  6.980401  242.864034    rice
# 4      78  42  42    20.130175  81.604873  7.628473  262.717340    rice
# ...   ...  ..  ..          ...        ...       ...         ...     ...
# 2195  107  34  32    26.774637  66.413269  6.780064  177.774507  coffee
# 2196   99  15  27    27.417112  56.636362  6.086922  127.924610  coffee
# 2197  118  33  30    24.131797  67.225123  6.362608  173.322839  coffee
# 2198  117  32  34    26.272418  52.127394  6.758793  127.175293  coffee
# 2199  104  18  30    23.603016  60.396475  6.779833  140.937041  coffee
#
# [2200 rows x 8 columns]

# %%
X=dataset.iloc[:,:-1].values

# %%
X
# Out:
# array([[ 90.        ,  42.        ,  43.        , ...,  82.00274423,
#           6.50298529, 202.9355362 ],
#        [ 85.        ,  58.        ,  41.        , ...,  80.31964408,
#           7.03809636, 226.6555374 ],
#        [ 60.        ,  55.        ,  44.        , ...,  82.3207629 ,
#           7.84020714, 263.9642476 ],
#        ...,
#        [118.        ,  33.        ,  30.        , ...,  67.22512329,
#           6.36260785, 173.3228386 ],
#        [117.        ,  32.        ,  34.        , ...,  52.12739421,
#           6.75879255, 127.1752928 ],
#        [104.        ,  18.        ,  30.        , ...,  60.39647474,
#           6.77983261, 140.9370415 ]])

# %%
y=dataset.iloc[:,-1].values

# %%
y
# Out:
# array(['rice', 'rice', 'rice', ..., 'coffee', 'coffee', 'coffee'],
#       dtype=object)

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test=train_test_split(X,y,test_size=0.2)

# %%
print(X_train.shape,X_test.shape)
print(y_train.shape,y_test.shape)
# Out:
# (1760, 7) (440, 7)
# (1760,) (440,)

# %%
from sklearn.neighbors import KNeighborsClassifier
ai=KNeighborsClassifier(n_neighbors=5)
ai.fit(X_train,y_train)
# Out:
# KNeighborsClassifier()

# %%
ai.predict([[70,60,50,48,84,8.5,200]])
# Out:
# array(['papaya'], dtype=object)

# %%
ai.predict(X_test)
# Out:
# array(['rice', 'mango', 'mango', 'cotton', 'pomegranate', 'watermelon',
#        'kidneybeans', 'maize', 'orange', 'coconut', 'watermelon',
#        'chickpea', 'grapes', 'jute', 'mango', 'coffee', 'papaya',
#        'blackgram', 'jute', 'muskmelon', 'cotton', 'pigeonpeas',
#        'pomegranate', 'banana', 'banana', 'mango', 'jute', 'lentil',
#        'pomegranate', 'jute', 'coffee', 'cotton', 'mango', 'coconut',
#        'coconut', 'maize', 'papaya', 'mango', 'blackgram', 'rice',
#        'banana', 'maize', 'watermelon', 'pigeonpeas', 'jute',
#        'watermelon', 'coconut', 'coffee', 'blackgram', 'grapes', 'rice',
#        'muskmelon', 'kidneybeans', 'kidneybeans', 'papaya', 'coconut',
#        'jute', 'jute', 'mungbean', 'chickpea', 'coffee', 'kidneybeans',
#        'mango', 'kidneybeans', 'mango', 'papaya', 'cotton', 'pomegranate',
#        'cotton', 'lentil', 'kidneybeans', 'jute', 'pigeonpeas',
#        'blackgram', 'chickpea', 'papaya', 'cotton', 'pigeonpeas',
#        'mungbean', 'papaya', 'lentil', 'apple', 'kidneybeans',
#        'pomegranate', 'mungbean', 'mothbeans', 'mungbean', 'chickpea',
#        'lentil', 'jute', 'maize', 'banana', 'mungbean', 'coffee',
#        'cotton', 'banana', 'apple', 'rice', 'mungbean', 'muskmelon',
#        'pomegranate', 'kidneybeans', 'rice', 'orange', 'mango', 'apple',
#        'kidneybeans', 'maize', 'cotton', 'maize', 'mothbeans',
#        'kidneybeans', 'kidneybeans', 'papaya', 'pigeonpeas', 'banana',
#        'mothbeans', 'blackgram', 'lentil', 'muskmelon', 'jute', 'lentil',
#        'blackgram', 'jute', 'pomegranate', 'orange', 'papaya', 'chickpea',
#        'coconut', 'mothbeans', 'rice', 'cotton', 'chickpea', 'mungbean',
#        'mothbeans', 'orange', 'apple', 'rice', 'coffee', 'watermelon',
#        'watermelon', 'muskmelon', 'apple', 'apple', 'banana', 'maize',
#        'mothbeans', 'mothbeans', 'maize', 'lentil', 'maize', 'mungbean',
#        'coconut', 'pigeonpeas', 'lentil', 'coffee', 'apple', 'pigeonpeas',
#        'kidneybeans', 'blackgram', 'chickpea', 'mothbeans', 'mango',
#        'apple', 'grapes', 'mungbean', 'apple', 'jute', 'cotton', 'banana',
#        'chickpea', 'mungbean', 'coffee', 'apple', 'apple', 'coconut',
#        'papaya', 'rice', 'chickpea', 'cotton', 'grapes', 'papaya',
#        'mungbean', 'papaya', 'maize', 'pomegranate', 'grapes', 'lentil',
#        'banana', 'jute', 'jute', 'muskmelon', 'muskmelon', 'blackgram',
#        'chickpea', 'jute', 'coconut', 'maize', 'muskmelon', 'kidneybeans',
#        'maize', 'papaya', 'maize', 'lentil', 'papaya', 'apple', 'apple',
#        'banana', 'grapes', 'cotton', 'lentil', 'orange', 'maize',
#        'chickpea', 'kidneybeans', 'papaya', 'jute', 'mango', 'banana',
#        'apple', 'coconut', 'jute', 'watermelon', 'mothbeans', 'cotton',
#        'mungbean', 'orange', 'apple', 'chickpea', 'maize', 'watermelon',
#        'rice', 'papaya', 'lentil', 'pigeonpeas', 'apple', 'watermelon',
#        'pigeonpeas', 'pigeonpeas', 'banana', 'muskmelon', 'banana',
#        'watermelon', 'mothbeans', 'pigeonpeas', 'mothbeans', 'watermelon',
#        'pomegranate', 'coconut', 'blackgram', 'lentil', 'blackgram',
#        'banana', 'kidneybeans', 'grapes', 'cotton', 'banana', 'muskmelon',
#        'lentil', 'apple', 'maize', 'banana', 'papaya', 'cotton', 'banana',
#        'rice', 'coffee', 'papaya', 'kidneybeans', 'mango', 'blackgram',
#        'muskmelon', 'coconut', 'chickpea', 'maize', 'kidneybeans', 'jute',
#        'banana', 'banana', 'apple', 'muskmelon', 'jute', 'mothbeans',
#        'jute', 'rice', 'papaya', 'mungbean', 'mango', 'jute', 'banana',
#        'pomegranate', 'banana', 'mothbeans', 'lentil', 'pomegranate',
#        'mungbean', 'muskmelon', 'rice', 'mango', 'orange', 'mango',
#        'lentil', 'pomegranate', 'orange', 'mungbean', 'banana', 'coconut',
#        'blackgram', 'cotton', 'banana', 'watermelon', 'coffee', 'coffee',
#        'mungbean', 'papaya', 'rice', 'mungbean', 'maize', 'pomegranate',
#        'jute', 'watermelon', 'mango', 'blackgram', 'rice', 'orange',
#        'rice', 'grapes', 'rice', 'apple', 'jute', 'muskmelon', 'mungbean',
#        'papaya', 'maize', 'pigeonpeas', 'watermelon', 'lentil',
#        'blackgram', 'coffee', 'watermelon', 'pigeonpeas', 'pigeonpeas',
#        'kidneybeans', 'grapes', 'jute', 'jute', 'blackgram', 'muskmelon',
#        'pigeonpeas', 'coffee', 'grapes', 'muskmelon', 'cotton',
#        'chickpea', 'mungbean', 'cotton', 'banana', 'coconut', 'orange',
#        'rice', 'watermelon', 'chickpea', 'rice', 'mungbean', 'maize',
#        'rice', 'papaya', 'banana', 'mothbeans', 'grapes', 'coffee',
#        'maize', 'cotton', 'mothbeans', 'chickpea', 'chickpea', 'jute',
#        'jute', 'blackgram', 'apple', 'apple', 'mothbeans', 'mango',
#        'blackgram', 'mothbeans', 'grapes', 'rice', 'lentil',
#        'kidneybeans', 'coffee', 'apple', 'pomegranate', 'chickpea',
#        'mango', 'banana', 'maize', 'chickpea', 'lentil', 'apple',
#        'coffee', 'apple', 'pomegranate', 'blackgram', 'orange',
#        'blackgram', 'pomegranate', 'cotton', 'muskmelon', 'pigeonpeas',
#        'pigeonpeas', 'mango', 'chickpea', 'muskmelon', 'kidneybeans',
#        'rice', 'blackgram', 'muskmelon', 'mungbean', 'lentil',
#        'pigeonpeas', 'lentil', 'kidneybeans', 'mango', 'pigeonpeas',
#        'cotton', 'papaya', 'blackgram', 'jute', 'blackgram',
#        'kidneybeans', 'maize', 'papaya', 'coffee', 'banana', 'orange',
#        'orange', 'jute', 'muskmelon', 'pigeonpeas', 'mango'], dtype=object)

# %%
from sklearn.metrics import accuracy_score
y_ai = ai.predict(X_test)
print(accuracy_score(y_ai, y_test)*100)
# Out:
# 98.18181818181819
